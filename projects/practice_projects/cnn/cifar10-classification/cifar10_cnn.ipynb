# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 316s 2us/step

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))

model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))

# model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
# model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))

# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))

# model.add(Dense(512, activation='relu'))

model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_120 (Conv2D)          (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_71 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_123 (Conv2D)          (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_72 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_62 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_63 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 595,498
# Trainable params: 595,498
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='nadam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 19s - loss: 1.5704 - acc: 0.4278 - val_loss: 1.2317 - val_acc: 0.5558
#
# Epoch 00001: val_loss improved from inf to 1.23172, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 18s - loss: 1.1711 - acc: 0.5839 - val_loss: 1.1458 - val_acc: 0.5922
#
# Epoch 00002: val_loss improved from 1.23172 to 1.14576, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 18s - loss: 1.0653 - acc: 0.6223 - val_loss: 0.9479 - val_acc: 0.6832
#
# Epoch 00003: val_loss improved from 1.14576 to 0.94789, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 18s - loss: 0.9945 - acc: 0.6467 - val_loss: 0.9678 - val_acc: 0.6678
#
# Epoch 00004: val_loss did not improve from 0.94789
# Epoch 5/100
#  - 18s - loss: 0.9476 - acc: 0.6646 - val_loss: 0.8898 - val_acc: 0.6928
#
# Epoch 00005: val_loss improved from 0.94789 to 0.88982, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 18s - loss: 0.9137 - acc: 0.6768 - val_loss: 0.8471 - val_acc: 0.7130
#
# Epoch 00006: val_loss improved from 0.88982 to 0.84709, saving model to model.weights.best.hdf5
# Epoch 7/100
#  - 18s - loss: 0.8934 - acc: 0.6890 - val_loss: 0.8788 - val_acc: 0.6958
#
# Epoch 00007: val_loss did not improve from 0.84709
# Epoch 8/100
#  - 18s - loss: 0.8615 - acc: 0.6997 - val_loss: 0.8373 - val_acc: 0.7102
#
# Epoch 00008: val_loss improved from 0.84709 to 0.83733, saving model to model.weights.best.hdf5
# Epoch 9/100
#  - 18s - loss: 0.8487 - acc: 0.7026 - val_loss: 0.7963 - val_acc: 0.7326
#
# Epoch 00009: val_loss improved from 0.83733 to 0.79633, saving model to model.weights.best.hdf5
# Epoch 10/100
#  - 18s - loss: 0.8399 - acc: 0.7054 - val_loss: 0.7772 - val_acc: 0.7366
#
# Epoch 00010: val_loss improved from 0.79633 to 0.77717, saving model to model.weights.best.hdf5
# Epoch 11/100
#  - 18s - loss: 0.8241 - acc: 0.7119 - val_loss: 0.8490 - val_acc: 0.7112
#
# Epoch 00011: val_loss did not improve from 0.77717
# Epoch 12/100
#  - 18s - loss: 0.8178 - acc: 0.7159 - val_loss: 0.7760 - val_acc: 0.7368
#
# Epoch 00012: val_loss improved from 0.77717 to 0.77599, saving model to model.weights.best.hdf5
# Epoch 13/100
#  - 18s - loss: 0.8011 - acc: 0.7206 - val_loss: 0.7617 - val_acc: 0.7420
#
# Epoch 00013: val_loss improved from 0.77599 to 0.76167, saving model to model.weights.best.hdf5
# Epoch 14/100
#  - 18s - loss: 0.7911 - acc: 0.7259 - val_loss: 0.7314 - val_acc: 0.7482
#
# Epoch 00014: val_loss improved from 0.76167 to 0.73143, saving model to model.weights.best.hdf5
# Epoch 15/100
#  - 18s - loss: 0.7786 - acc: 0.7282 - val_loss: 0.7959 - val_acc: 0.7200
#
# Epoch 00015: val_loss did not improve from 0.73143
# Epoch 16/100
#  - 18s - loss: 0.7791 - acc: 0.7283 - val_loss: 0.7916 - val_acc: 0.7312
#
# Epoch 00016: val_loss did not improve from 0.73143
# Epoch 17/100
#  - 18s - loss: 0.7742 - acc: 0.7312 - val_loss: 0.7440 - val_acc: 0.7434
#
# Epoch 00017: val_loss did not improve from 0.73143
# Epoch 18/100
#  - 18s - loss: 0.7663 - acc: 0.7342 - val_loss: 0.7494 - val_acc: 0.7442
#
# Epoch 00018: val_loss did not improve from 0.73143
# Epoch 19/100
#  - 18s - loss: 0.7659 - acc: 0.7352 - val_loss: 0.7447 - val_acc: 0.7502
#
# Epoch 00019: val_loss did not improve from 0.73143
# Epoch 20/100
#  - 18s - loss: 0.7582 - acc: 0.7371 - val_loss: 0.7310 - val_acc: 0.7492
#
# Epoch 00020: val_loss improved from 0.73143 to 0.73102, saving model to model.weights.best.hdf5
# Epoch 21/100
#  - 18s - loss: 0.7478 - acc: 0.7406 - val_loss: 0.7586 - val_acc: 0.7426
#
# Epoch 00021: val_loss did not improve from 0.73102
# Epoch 22/100
#  - 18s - loss: 0.7502 - acc: 0.7419 - val_loss: 0.7461 - val_acc: 0.7384
#
# Epoch 00022: val_loss did not improve from 0.73102
# Epoch 23/100
#  - 18s - loss: 0.7490 - acc: 0.7404 - val_loss: 0.7276 - val_acc: 0.7554
#
# Epoch 00023: val_loss improved from 0.73102 to 0.72760, saving model to model.weights.best.hdf5
# Epoch 24/100
#  - 18s - loss: 0.7345 - acc: 0.7464 - val_loss: 0.7258 - val_acc: 0.7506
#
# Epoch 00024: val_loss improved from 0.72760 to 0.72576, saving model to model.weights.best.hdf5
# Epoch 25/100
#  - 18s - loss: 0.7276 - acc: 0.7476 - val_loss: 0.7319 - val_acc: 0.7518
#
# Epoch 00025: val_loss did not improve from 0.72576
# Epoch 26/100
#  - 18s - loss: 0.7257 - acc: 0.7473 - val_loss: 0.7504 - val_acc: 0.7514
#
# Epoch 00026: val_loss did not improve from 0.72576
# Epoch 27/100
#  - 18s - loss: 0.7225 - acc: 0.7503 - val_loss: 0.7203 - val_acc: 0.7526
#
# Epoch 00027: val_loss improved from 0.72576 to 0.72028, saving model to model.weights.best.hdf5
# Epoch 28/100
#  - 18s - loss: 0.7230 - acc: 0.7505 - val_loss: 0.7522 - val_acc: 0.7574
#
# Epoch 00028: val_loss did not improve from 0.72028
# Epoch 29/100
#  - 18s - loss: 0.7245 - acc: 0.7497 - val_loss: 0.7809 - val_acc: 0.7356
#
# Epoch 00029: val_loss did not improve from 0.72028
# Epoch 30/100
#  - 18s - loss: 0.7174 - acc: 0.7513 - val_loss: 0.7189 - val_acc: 0.7590
#
# Epoch 00030: val_loss improved from 0.72028 to 0.71892, saving model to model.weights.best.hdf5
# Epoch 31/100
#  - 18s - loss: 0.7119 - acc: 0.7529 - val_loss: 0.7460 - val_acc: 0.7470
#
# Epoch 00031: val_loss did not improve from 0.71892
# Epoch 32/100
#  - 18s - loss: 0.7124 - acc: 0.7538 - val_loss: 0.6991 - val_acc: 0.7698
#
# Epoch 00032: val_loss improved from 0.71892 to 0.69913, saving model to model.weights.best.hdf5
# Epoch 33/100
#  - 18s - loss: 0.7013 - acc: 0.7591 - val_loss: 0.7202 - val_acc: 0.7560
#
# Epoch 00033: val_loss did not improve from 0.69913
# Epoch 34/100
#  - 18s - loss: 0.7006 - acc: 0.7560 - val_loss: 0.7154 - val_acc: 0.7590
#
# Epoch 00034: val_loss did not improve from 0.69913
# Epoch 35/100
#  - 18s - loss: 0.6983 - acc: 0.7592 - val_loss: 0.8132 - val_acc: 0.7266
#
# Epoch 00035: val_loss did not improve from 0.69913
# Epoch 36/100
#  - 18s - loss: 0.7054 - acc: 0.7577 - val_loss: 0.7688 - val_acc: 0.7380
#
# Epoch 00036: val_loss did not improve from 0.69913
# Epoch 37/100
#  - 18s - loss: 0.6943 - acc: 0.7618 - val_loss: 0.7561 - val_acc: 0.7448
#
# Epoch 00037: val_loss did not improve from 0.69913
# Epoch 38/100
#  - 18s - loss: 0.6890 - acc: 0.7611 - val_loss: 0.7104 - val_acc: 0.7586
#
# Epoch 00038: val_loss did not improve from 0.69913
# Epoch 39/100
#  - 18s - loss: 0.6993 - acc: 0.7572 - val_loss: 0.7435 - val_acc: 0.7480
#
# Epoch 00039: val_loss did not improve from 0.69913
# Epoch 40/100
#  - 18s - loss: 0.6894 - acc: 0.7644 - val_loss: 0.7209 - val_acc: 0.7640
#
# Epoch 00040: val_loss did not improve from 0.69913
# Epoch 41/100
#  - 18s - loss: 0.6897 - acc: 0.7634 - val_loss: 0.7141 - val_acc: 0.7568
#
# Epoch 00041: val_loss did not improve from 0.69913
# Epoch 42/100
#  - 18s - loss: 0.6857 - acc: 0.7639 - val_loss: 0.7220 - val_acc: 0.7546
#
# Epoch 00042: val_loss did not improve from 0.69913
# Epoch 43/100
#  - 18s - loss: 0.6756 - acc: 0.7680 - val_loss: 0.7320 - val_acc: 0.7502
#
# Epoch 00043: val_loss did not improve from 0.69913
# Epoch 44/100
#  - 18s - loss: 0.6919 - acc: 0.7640 - val_loss: 0.7701 - val_acc: 0.7414
#
# Epoch 00044: val_loss did not improve from 0.69913
# Epoch 45/100
#  - 18s - loss: 0.6683 - acc: 0.7706 - val_loss: 0.7392 - val_acc: 0.7422
#
# Epoch 00045: val_loss did not improve from 0.69913
# Epoch 46/100
#  - 18s - loss: 0.6734 - acc: 0.7688 - val_loss: 0.7269 - val_acc: 0.7526
#
# Epoch 00046: val_loss did not improve from 0.69913
# Epoch 47/100
#  - 18s - loss: 0.6874 - acc: 0.7639 - val_loss: 0.7297 - val_acc: 0.7496
#
# Epoch 00047: val_loss did not improve from 0.69913
# Epoch 48/100
#  - 18s - loss: 0.6822 - acc: 0.7649 - val_loss: 0.7295 - val_acc: 0.7510
#
# Epoch 00048: val_loss did not improve from 0.69913
# Epoch 49/100
#  - 18s - loss: 0.6758 - acc: 0.7694 - val_loss: 0.7744 - val_acc: 0.7352
#
# Epoch 00049: val_loss did not improve from 0.69913
# Epoch 50/100
#  - 18s - loss: 0.6812 - acc: 0.7682 - val_loss: 0.7064 - val_acc: 0.7542
#
# Epoch 00050: val_loss did not improve from 0.69913
# Epoch 51/100
#  - 18s - loss: 0.6801 - acc: 0.7677 - val_loss: 0.7347 - val_acc: 0.7526
#
# Epoch 00051: val_loss did not improve from 0.69913
# Epoch 52/100
#  - 18s - loss: 0.6739 - acc: 0.7714 - val_loss: 0.7563 - val_acc: 0.7590
#
# Epoch 00052: val_loss did not improve from 0.69913
# Epoch 53/100
#  - 18s - loss: 0.6870 - acc: 0.7666 - val_loss: 0.7758 - val_acc: 0.7408
#
# Epoch 00053: val_loss did not improve from 0.69913
# Epoch 54/100
#  - 18s - loss: 0.6713 - acc: 0.7705 - val_loss: 0.7230 - val_acc: 0.7606
#
# Epoch 00054: val_loss did not improve from 0.69913
# Epoch 55/100
#  - 18s - loss: 0.6711 - acc: 0.7707 - val_loss: 0.7173 - val_acc: 0.7496
#
# Epoch 00055: val_loss did not improve from 0.69913
# Epoch 56/100
#  - 18s - loss: 0.6752 - acc: 0.7696 - val_loss: 0.7420 - val_acc: 0.7474
#
# Epoch 00056: val_loss did not improve from 0.69913
# Epoch 57/100
#  - 18s - loss: 0.6789 - acc: 0.7677 - val_loss: 0.7288 - val_acc: 0.7530
#
# Epoch 00057: val_loss did not improve from 0.69913
# Epoch 58/100
#  - 18s - loss: 0.6792 - acc: 0.7699 - val_loss: 0.7450 - val_acc: 0.7460
#
# Epoch 00058: val_loss did not improve from 0.69913
# Epoch 59/100
#  - 18s - loss: 0.6744 - acc: 0.7721 - val_loss: 0.7345 - val_acc: 0.7578
#
# Epoch 00059: val_loss did not improve from 0.69913
# Epoch 60/100
#  - 18s - loss: 0.6604 - acc: 0.7755 - val_loss: 0.7182 - val_acc: 0.7580
#
# Epoch 00060: val_loss did not improve from 0.69913
# Epoch 61/100
#  - 18s - loss: 0.6641 - acc: 0.7753 - val_loss: 0.7836 - val_acc: 0.7374
#
# Epoch 00061: val_loss did not improve from 0.69913
# Epoch 62/100
#  - 18s - loss: 0.6688 - acc: 0.7718 - val_loss: 0.7342 - val_acc: 0.7448
#
# Epoch 00062: val_loss did not improve from 0.69913
# Epoch 63/100
#  - 18s - loss: 0.6550 - acc: 0.7775 - val_loss: 0.7210 - val_acc: 0.7560
#
# Epoch 00063: val_loss did not improve from 0.69913
# Epoch 64/100
#  - 18s - loss: 0.6554 - acc: 0.7787 - val_loss: 0.7318 - val_acc: 0.7566
#
# Epoch 00064: val_loss did not improve from 0.69913
# Epoch 65/100
#  - 18s - loss: 0.6526 - acc: 0.7766 - val_loss: 0.7392 - val_acc: 0.7466
#
# Epoch 00065: val_loss did not improve from 0.69913
# Epoch 66/100
#  - 18s - loss: 0.6649 - acc: 0.7749 - val_loss: 0.7423 - val_acc: 0.7494
#
# Epoch 00066: val_loss did not improve from 0.69913
# Epoch 67/100
#  - 18s - loss: 0.6519 - acc: 0.7779 - val_loss: 0.7255 - val_acc: 0.7542
#
# Epoch 00067: val_loss did not improve from 0.69913
# Epoch 68/100
#  - 18s - loss: 0.6533 - acc: 0.7768 - val_loss: 0.7271 - val_acc: 0.7574
#
# Epoch 00068: val_loss did not improve from 0.69913
# Epoch 69/100
#  - 18s - loss: 0.6512 - acc: 0.7786 - val_loss: 0.7712 - val_acc: 0.7410
#
# Epoch 00069: val_loss did not improve from 0.69913
# Epoch 70/100
#  - 18s - loss: 0.6589 - acc: 0.7744 - val_loss: 0.7265 - val_acc: 0.7582
#
# Epoch 00070: val_loss did not improve from 0.69913
# Epoch 71/100
#  - 18s - loss: 0.6491 - acc: 0.7813 - val_loss: 0.7121 - val_acc: 0.7590
#
# Epoch 00071: val_loss did not improve from 0.69913
# Epoch 72/100
#  - 18s - loss: 0.6557 - acc: 0.7780 - val_loss: 0.7357 - val_acc: 0.7564
#
# Epoch 00072: val_loss did not improve from 0.69913
# Epoch 73/100
#  - 18s - loss: 0.6453 - acc: 0.7799 - val_loss: 0.7199 - val_acc: 0.7594
#
# Epoch 00073: val_loss did not improve from 0.69913
# Epoch 74/100
#  - 18s - loss: 0.6599 - acc: 0.7772 - val_loss: 0.7681 - val_acc: 0.7390
#
# Epoch 00074: val_loss did not improve from 0.69913
# Epoch 75/100
#  - 18s - loss: 0.6556 - acc: 0.7756 - val_loss: 0.7588 - val_acc: 0.7456
#
# Epoch 00075: val_loss did not improve from 0.69913
# Epoch 76/100

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7613

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
